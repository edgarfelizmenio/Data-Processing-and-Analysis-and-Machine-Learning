# %% [markdown]
# <a href="https://colab.research.google.com/github/edgarfelizmenio/Data-Processing-and-Analysis-and-Machine-Learning/blob/main/Day_1_Data_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Collection

# %% [markdown]
# ### **Method 1:** Using `wget`

# %% [markdown]
# ### **Method 2:** From a local directory / Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Using Pandas to Manipulate Data

# %% [markdown]
# ### Basic Terminologies

# %% [markdown]
# What is a Series?

# %% [markdown]
# ![series.png](data:image/png;base64,...)

# %% [markdown]
# What is a Dataframe?

# %% [markdown]
# ![dataframe.png](data:image/png;base64,...)

# %% [markdown]
# ### Installing Pandas

# %% [markdown]
# ### Reading data
# How do we open our data file in Pandas?

# %% [markdown]
# ### Checking contents of data

# %% [markdown]
# How many rows and columns does our data have?

# %% [markdown]
# What does our data look like?

# %% [markdown]
# ### Selecting certain columnn/columns

# %% [markdown]
# How do we select a single column?

# %% [markdown]
# How do we select multiple columns?

# %% [markdown]
# How do we select based on a condition?

# %% [markdown]
# ### Performing an operation on a column

# %% [markdown]
# ### Cleaning the data

# %% [markdown]
# 1. **Removing duplicates**

# %% [markdown]
# 2. **Check for inconsistencies**

# %% [markdown]
# 3. **Missing Values**

# %% [markdown]
# >>>**a. Numeric**

# %%
# Mean (Normal Distribution)

# %%
# Median (Skewed Distribution)

# %% [markdown]
# >>> **b. Categorical**

# %%
# Mode

# %% [markdown]
# 4. **Outliers**

# %%
# Boxplot

# %% [markdown]
# ![boxplot.png](data:image/png;base64,...)

# %%
# Removing Outliers

# %% [markdown]
# ### Saving Cleaned Data

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# ### Mean

# %% [markdown]
# ### Median

# %% [markdown]
# ### Count

# %% [markdown]
# ### Summary

# %% [markdown]
# ## Distribution of Values

# %% [markdown]
# ## Relationship between two variables

# %% [markdown]
# ## Boxplots for determining variables

# %% [markdown]
# ## Pandas Profiling

# %% [markdown]
# # Data Modeling (Pre-machine learning)

# %% [markdown]
# ## One-hot encoding categorical

# %% [markdown]
# ## Selecting features to use

# %% [markdown]
# ### Backed up by previous studies

# %% [markdown]
# ### Best judgement

# %% [markdown]
# ### Use all

# %% [markdown]
# # Preparing data for Machine Learning (NEXT PART)

# %% [markdown]
# # Data Modeling (Machine Learning)

# %% [markdown]
# ## Selecting a machine learning algorithm

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# ## Training final model

# %% [markdown]
# ## Evaluating the model (Performance Metrics)

# %% [markdown]
# # Data Visualization (Output)
